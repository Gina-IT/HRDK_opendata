# %%
import pandas as pd

# %%
api_team3= pd.read_csv("./api_team3.csv")
api_team3
# Out:
#                           open API         부서       파일형식   조회수  활용신청    활용률  \
# 0                     일학습병행제 정보 조회  일학습과정개발센터  XML/ JSON  1050    43  4.10%
# 1          일학습병행자격 종목별 NCS 능력단위 정보  일학습과정개발센터  XML/ JSON  1079    24  2.22%
# 2               과정평가형, 일학습병행 통계 정보  일학습과정개발센터  XML/ JSON  1021    19  1.86%
# 3        과정평가형일학습병행 홈페이지 관리 정보 서비스  일학습과정개발센터  XML/ JSON   811    11  1.36%
# 4                과정형가형, 일학습병행 통계연보  일학습과정개발센터  XML/ JSON  1081    12  1.11%
# 5       과정평가형일학습병행 설문 관련 정보 조회 서비스  일학습과정개발센터  XML/ JSON   802     8  1.00%
# 6  과정평가형일학습병행 과정 지정평가 관련 정보 조회 서비스  일학습과정개발센터  XML/ JSON   756     7  0.93%
# 7          과정평가형일학습병행 출제 관련 정보 서비스  일학습과정개발센터  XML/ JSON   770     7  0.91%
# 8        과정평가형일학습병행 모니터링 일정 정보 서비스  일학습과정개발센터  XML/ JSON   797     6  0.75%
# 9    과정평가형일학습병행 외부평가 채점결과 연계이력 서비스  일학습과정개발센터  XML/ JSON   765     5  0.65%
#
#           수정일
# 0  2018-09-17
# 1  2018-08-17
# 2  2019-08-14
# 3  2020-09-01
# 4  2019-08-14
# 5  2020-09-01
# 6  2020-09-01
# ...

# %%
api_team2= pd.read_csv("./api_team2.csv")
api_team2
# Out:
#                     open API       부서       파일형식   조회수  활용신청     활용률  \
# 0                     해외진출정보  정보화사업2부        XML  2721   372  13.67%
# 1                한국직업방송 프로그램  정보화사업2부        XML  1090   115  10.55%
# 2                  해외취업 통계정보  정보화사업2부        XML  3731   186   4.99%
# 3               NCS관련 정보 서비스  정보화사업2부  XML/ JSON  1178    40   3.40%
# 4                국가직무능력표준 정보  정보화사업2부        XML  4070   132   3.24%
# 5     과정평가형자격 종목별 NCS능력단위 정보  정보화사업2부  XML/ JSON  1019    29   2.85%
# 6        NCS 고교직업교육과정 정보 서비스  정보화사업2부        XML   808    11   1.36%
# 7     NCS 능력단위별 자격 종목 조회 서비스  정보화사업2부        XML   874    11   1.26%
# 8             NCS 설명회 정보 서비스  정보화사업2부        XML   722     9   1.25%
# 9    자격취득자 교육훈련 시스템 과정정보 서비스  정보화사업2부        XML   734     8   1.09%
# 10                기능경기 관련 정보  정보화사업2부        XML   707     5   0.71%
# 11   자격취득자 교육훈련 시스템 영상정보 서비스  정보화사업2부        XML   716     4   0.56%
# 12           마이스터넷 신청 정보 서비스  정보화사업2부        XML   910     4   0.44%
# ...
