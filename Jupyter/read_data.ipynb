# %%
# !pip install pandas

# %%
import pandas as pd

# %%
engineer_stats= pd.read_csv("./DATA/2021년 국가기술자격 통계 기사.csv", encoding='utf-8')
engineer_stats
# Out:
#        종목명        년도  성별    필기시험접수   필기시험응시   필기시험합격  필기시험합격률(%)   실기시험접수  \
# 0     기사합계        전체  전체  12768971  9173922  3374690        36.8  6376359
# 1     기사합계  2015(누적)  전체  10345992  7402481  2641944        35.7  5030726
# 2     기사합계      2016  전체    451651   324625   125203        38.6   219527
# 3     기사합계      2016  여자     89468    68080    28951        42.5    47175
# 4     기사합계      2017  전체    468829   340250   128581        37.8   236142
# ...    ...       ...  ..       ...      ...      ...         ...      ...
# 1891  기상감정      2018  여자        21       14       10        71.4       16
# 1892  기상감정      2019  전체        84       62       42        67.7       53
# 1893  기상감정      2019  여자        23       16       12        75.0       17
# 1894  기상감정      2020  전체        82       53       36        67.9       38
# 1895  기상감정      2020  여자        44       30       23        76.7       24
#
#        실기시험응시   실기시험합격  실기시험합격률(%)  자격취득자현황(명)
# ...

# %%
cbt_subjs_by_time= pd.read_csv("./DATA/한국산업인력공단_국가자격 CBT 교시과목 정보_20200619.csv", encoding='cp949')
cbt_subjs_by_time
# Out:
#                종목명          과목명  과목순서  교시번호  문항수  수험시간_분       등록일
# 0         중식조리산업기사          식품학     2     1   20      30  20/08/07
# 1         중식조리산업기사  식품위생 및 관련법규     1     1   20      30  20/08/07
# 2         중식조리산업기사        공중보건학     4     1   20      30  20/08/07
# 3     아스팔트피니셔운전기능사         과목없음     1     1   60      60  14/09/24
# 4           금속재료기사         표면공학     5     1   20      30  14/09/24
# ...            ...          ...   ...   ...  ...     ...       ...
# 1315      가구제작산업기사         가구재료     2     1   20      30  20/08/07
# 1316        신발산업기사      신발견본 개발     2     1   20      30  20/10/14
# 1317        신발산업기사  신발 기획 및 디자인     0     1   20      30  20/10/14
# 1318        신발산업기사        신발 설계     1     1   20      30  20/10/14
# 1319        포장산업기사      포장재료및시험     2     1   20      30  21/02/05
#
# [1320 rows x 7 columns]

# %%
cbt_loca_examinee= pd.read_csv("./DATA/한국산업인력공단_국가자격 CBT 시험장소 및 수험자 정보_20200427.csv", encoding='cp949')
cbt_loca_examinee
# Out:
#              시행계획번호  수험자_차수   지사명                       시험장소         시험일  부  \
# 0      PL2020522014       1    서울     서울국가자격시험장(휘경동)[CBT 1실]  2020-02-09  1
# 1      PL2020522014       1    서울     서울국가자격시험장(휘경동)[CBT 1실]  2020-02-09  3
# 2      PL2020522014       1    서울     서울국가자격시험장(휘경동)[CBT 1실]  2020-02-09  5
# 3      PL2020522014       1    서울     서울국가자격시험장(휘경동)[CBT 1실]  2020-02-09  7
# 4      PL2020522014       1    서울     서울국가자격시험장(휘경동)[CBT 1실]  2020-02-09  9
# ...             ...     ...   ...                        ...         ... ..
# 61536  PL2021533117      11  경기동부  폴리텍대학(성남)드림관(CBT시험실) [6실]  2021-03-14  2
# 61537  PL2021533117      11  경기동부  폴리텍대학(성남)드림관(CBT시험실) [6실]  2021-03-14  4
# 61538  PL2021533117      11  경기동부  폴리텍대학(성남)드림관(CBT시험실) [7실]  2021-03-14  1
# 61539  PL2021533117      11  경기동부  폴리텍대학(성남)드림관(CBT시험실) [7실]  2021-03-14  2
# 61540  PL2021533117      11  경기동부  폴리텍대학(성남)드림관(CBT시험실) [7실]  2021-03-14  4
#
#        행수  열수 좌석번호_방향  수험자_수험대상
# ...

# %%
cbt_stats= pd.read_csv("./DATA/한국산업인력공단_국가자격 CBT 통계 및 현황 정보_20201231.csv", encoding='cp949')
cbt_stats
# Out:
#        시행년도  시행월       시행일  시행회차  등급명 시행구분        종목명 지사명  응시자수  결시자수  중도포기자수  \
# 0      2020    1  20200119     1  기능사   상시   굴삭기운전기능사  서울    21     0       0
# 1      2020    1  20200119     1  기능사   상시      제과기능사  서울    20     1       0
# 2      2020    1  20200119     1  기능사   상시    양식조리기능사  서울    22     6       0
# 3      2020    1  20200119     1  기능사   상시    미용사(네일)  서울    34     2       0
# 4      2020    1  20200119     1  기능사   상시      제빵기능사  서울    35     2       0
# ...     ...  ...       ...   ...  ...  ...        ...  ..   ...   ...     ...
# 68891  2020   12  20201224    42  기능사   상시  미용사(메이크업)  전남     3     1       0
# 68892  2020   12  20201224    42  기능사   상시    미용사(네일)  전남     6     0       0
# 68893  2020   12  20201224    42  기능사   상시   지게차운전기능사  전남    55    13       0
# 68894  2020   12  20201224    42  기능사   상시   굴삭기운전기능사  전남    36     6       0
# 68895  2020   12  20201224    42  기능사   상시    양식조리기능사  전남     5     0       0
#
# ...
