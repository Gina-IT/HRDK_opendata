# %% [markdown]
# ### 대학 학과 관련 자격 정보
# 1. 국가기술자격 대학별 학과 데이터- 국가기술자격 응시자격 사용되고 있는 대학별 학과 정보 코드 등 현황 제공
# - 대학별 학과 정보
# 2. 국가기술자격 취득 관련 현황- <u><b>국가기술자격 소지자 현황, 학력별 취득현황</b></u> 등 국가기술자격 정보 시스템에 등록되어 있는 취득관련 현황을 제공
# - 토목(산업)기사 자격취득자 현황
# - <b>전공별 취득현황</b>
# - <b>학력별 취득현황</b>
# - 취득자 연도별 현황 성별, 연령별, 학력별(수탁기관 현재년 기준)
# - 취득자 연도별 현황 성별, 연령별, 학력별(수탁기관)
# - 국방부 검정을 통한 종목별 자격취득자 현황
# - 행정구역별 연도별 성별 취득현황
# - <b>국가자격 취득소요기간</b>
# - 신설종목 취득현황
# 3. 국가자격 계열별 학과 정보 데이터- 청소년상담사 등 국가전문자격 계열별 학과 정보 목록을 조회할 수 있습니다.
# - 계열별 학과 정보 조회
# 4. 국가자격 취득자 관련 통계 정보- 국가자격 <u><b>취득자의 부처별 자격 현황</b></u>, 기술분야별 분류 현황 등 관련 세부 정보를 제공
# - 학력별 자격취득자 현황
# - 상시검정 취득자 현황
# - 연령별 검정 취득자 현황
# 5. 국가기술자격 학과별 직무정보- 국가기술자격 응시자격에 필요한 학과별 직무 정보를 제공
# - 학과별 직무조회
# 6. 자격정보 교과과정 정보- 국가 기술자격 정보 시스템에 등록되어 있는 자격정보 교과과정 정보를 제공한다.
# - 자격정보 교과과정 정보

# %% [markdown]
# ### 국가자격 관련 정보
# 1. 국가자격 종목별 자격정보- 국가자격 종목별 자격정보를 조회할 수 있습니다
# - 국가기술자격의 종목별 자격정보률 조회
# 2. 국가자격 계열 관련 정보- 국가 기술자격 정보 시스템에 등록되어 있는 국가자격 계열 관련 정보를 제공한다
# - 계열별 과목 매핑
# - 계열규칙
# 3. 자격정보 선택분야 정보- 국가 기술자격 정보 시스템에 등록되어 있는 자격정보 선택분야 정보를 제공
# - 자격정보 선택분야 정보
# ------------------------------------------------------------------------------------------------------------------
# 4. 국가자격 공개문제 조회 서비스- 자격구분, 종목 등을 기준으로 공개문제 게시물 아이디, 제목, 자격구분, 계열, 종목 등의 공개문제 목록 조회와 공개문제 게시물 아이디를 기준으로 공개문제 게시물 제목, 내용, 자격구분, 계열, 종목, 첨부파일 URL 등의 공개문제 상세 조회를 제공하는 국가자격 공개문제 조회 서비스
# - 국가자격 공개문제 목록 조회
# - 국가자격 공개문제 상세 조회

# %% [markdown]
# ### NCS관련
# 1. 블라인드 채용 기업- 블라인드 채용 기업별 분류 목록 제공
# - <b>블라인드 채용 기업 목록(NCS 코드 포함함)</b>
# 2. NCS 능력단위별 자격 종목 조회 서비스- NCS 능력단위를 기준으로 <u><b>해당 NCS 능력단위가 포함된 자격 종목 목록을 조회</b></u>하는 NCS 능력단위별 자격 종목 조회 서비스
# - NCS 능력단위별 자격 종목 조회 서비스
# 3. NCS 관련 정보 서비스- 능력단위코드, 능력단위명, 능력단위수준, 대분류명, 중분류명, 소분류명, 세분류명, 능력단위정의 등의 정보를 제공하는 "NCS 관련 정보"서비스로, "과정평가형, 일학습병행 정보 조회" API중 하나
# - NCS 관련 정보
